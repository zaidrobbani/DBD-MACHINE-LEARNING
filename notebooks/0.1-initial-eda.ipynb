# %% [markdown]
# # 0.1 - Initial EDA - MLOps-DBD
#
# Notebook eksplorasi awal (initial EDA), dibuat pada branch `feat/initial-eda`.
#
# Konvensi penamaan notebook: `<nomor>-<inisial>-<deskripsi-singkat>.ipynb`
# contoh: `0.1-zr-initial-eda.ipynb`, `0.2-zr-feature-exploration.ipynb`.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

df = pd.read_csv("../data/raw/dataset.csv")
df.head()

# %%
df.info()
df.describe()
